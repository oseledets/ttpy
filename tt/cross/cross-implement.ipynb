# %%
import numpy as np
from numpy.linalg import qr
import sys
sys.path.append("/Users/ivan/work/python/ttpy/") 
import tt
from tt.maxvol import maxvol
""" There are quantitites associated with edges; 
    There are quantitites associated with nodes; 
"""
def reshape(a, sz):
    return np.reshape(a, sz, order = 'F')

def mkron(a, b):
    return np.kron(a, b)


class node:
    def __init__(self):
        self.edges = [None for i in xrange(2)]
        
    
    """ Here we put in typical recipies for what we can do with a node """
    
    @staticmethod
    def left_qr_update(nd):
        cr = nd.core.copy()
        r1, n1, r2 = cr.shape
        cr = reshape(cr, (r1, n1 * r2))
        cr = np.dot(nd.edges[0].R, cr)
        r1 = cr.shape[0]
        cr = reshape(cr, (r1 * n1, r2))
        q, R = qr(cr)
        nd.core = reshape(q, (r1, n1, r2)).copy()
        nd.edges[1].R = R.copy()
    
class edge:
    def __init__(self):
        self.nodes = [None for i in xrange(2)]

    
    """ Here we put in typical recipies for what we can do with an edge """
    @staticmethod
    def init_qr_boundary(e):
        e.R = np.ones((1, 1))



            
    
class tt_as_tree:
    def __init__(self, d, node_type, edge_type, init_boundary = None):
        self.d = d
        self.nodes = [node_type() for i in xrange(d)]
        self.edges = [edge_type() for i in xrange(d + 1)]
        #  None - N - N - N - None
        for i in xrange(d):
            self.nodes[i].edges[0] = self.edges[i]
            self.nodes[i].edges[1] = self.edges[i + 1]
        
        if init_boundary is not None:
            init_boundary(self.edges[0])
            init_boundary(self.edges[d])
        
        for i in xrange(d - 1):
            self.edges[i].nodes[1] = self.nodes[i]
            self.edges[i + 1].nodes[0] = self.nodes[i]
        
        self.edges[0].nodes[0] = None
        self.edges[d].nodes[1] = None
        
    @staticmethod
    def from_tt(b, *args):
        c = tt_as_tree(b.d, *args)
        for i in xrange(b.d):
            c.nodes[i].core = b.core[b.ps[i] - 1:b.ps[i + 1] - 1].reshape(b.r[i], b.n[i], b.r[i + 1]).copy()
        return c

    def lr_sweep(self, node_update, edge_update=None):
        for i in xrange(self.d):
            node_update(self.nodes[i])
            if edge_update is not None:
                edge_update(self.edges[i + 1])

    def to_tt(self):
        core = [self.nodes[i].core for i in xrange(self.d)]
        return tt.tensor.from_list(core)


def left_qr_update(nd):
    cr = nd.core.copy()
    r1, n1, r2 = cr.shape
    cr = reshape(cr, (r1, n1 * r2))
    cr = np.dot(nd.edges[0].R, cr)
    r1 = cr.shape[0]
    cr = reshape(cr, (r1 * n1, r2))
    q, R = qr(cr)
    nd.core = reshape(q, (r1, n1, r2)).copy()
    nd.edges[1].R = R.copy()

def left_qr(R, Y):
    r1, n, m, r2 = Y.shape
    r1 = R.shape[1]
    Y = np.dot(R, reshape(Y, (r1, -1)))
    r1 = Y.shape[0]
    Y = reshape(Y, (r1 * n * m, r2))
    Y, R_new = np.linalg.qr(Y)
    Y = reshape(Y, (r1, n, m, -1))
    return Y, R_new


def right_qr(nd):
    Y = nd.Ycore
    R = nd.edges[1].R
    r1, n, m, r2 = Y.shape
    r2 = R.shape[0]
    Y = np.dot(reshape(Y, (-1, r2)), R)
    r2 = Y.shape[1]
    Y = reshape(Y, (r1, n * m * r2))
    Y = Y.T #Y is n m r2 x r1
    Y, R_new = np.linalg.qr(Y) # 
    Y = reshape(Y, (n, m, r2, -1))
    Y = np.transpose(Y, (3, 0, 1, 2))
    R_new = R_new.T
    nd.Ycore = Y.copy()
    nd.edges[0].R = R_new.copy()


def right_R(Y, R):
    r1, n, m, r2 = Y.shape
    r2 = R.shape[0]
    Y = np.dot(reshape(Y, (-1, r2)), R)
    Y = reshape(Y, (r1, n, m, -1))
    return Y


def left_R(nd):
    Y = nd.Ycore
    R = nd.edges[0].R
    r1, n, m, r2 = Y.shape
    r1 = R.shape[1]
    Y = np.dot(R, reshape(Y, (r1, -1)))
    Y = reshape(Y, (-1, n, m, r2))
    nd.Ycore = Y


def left_qr(nd):
    Y = nd.Ycore
    r1, n, m, r2 = Y.shape
    Y = reshape(Y, (r1 * n * m, r2))
    Y, R_new = np.linalg.qr(Y)
    Y = reshape(Y, (r1, n, m, -1))
    nd.Ycore = Y
    nd.edges[1].R = R_new.copy()




def init_alg(fun, x0):
    d = x0.d
    c = tt_as_tree(d, node, edge)
    x1 = tt.tensor.to_list(x0)
    c.fun = fun #Save the function
    for i in xrange(d):
        c.nodes[i].ucore = x1[i].copy()
        c.nodes[i].vcore = x1[i].copy()
    for i in xrange(d+1):
        c.edges[i].Ru = []
        c.edges[i].Rv = []
    
    c.edges[0].Ru = np.ones((1, 1))
    c.edges[d].Rv = np.ones((1, 1))
    c.edges[0].ind_left = np.empty((1, 0), dtype=np.int32)
    c.edges[d].ind_right = np.empty((1, 0), dtype=np.int32)
    return c



def lr_sweep(c):
    d = c.d
    for i in xrange(d - 1):
        ##Put the R inside
        nd = c.nodes[i]
        pass

def get_uY(c):
    d = c.d
    Y = [c.nodes[i].ucore for i in xrange(d)]
    #Y = tt.tensor.from_list(Y)
    return Y


def get_vY(c):
    d = c.d
    Y = [c.nodes[i].vcore for i in xrange(d)]
    #Y = tt.tensor.from_list(Y)
    return Y

# %%
""" Main new functions """ 
def left_qr_maxvol(nd):
    cr = nd.ucore.copy()
    r1, n1, r2 = cr.shape
    cr = np.tensordot(nd.edges[0].Ru, cr, 1)
    #nd.edges[0].Ru = np.ones((1, 1))
    r1 = cr.shape[0]
    cr = reshape(cr, (r1 * n1, r2))
    q, Ru = qr(cr)
    ind = maxvol(q)
    Ru = np.dot(q[ind, :], Ru)
    q = np.linalg.solve(q[ind, :].T, q.T).T
    nd.ucore = reshape(q, (r1, n1, r2)).copy()
    nd.edges[1].Ru = Ru.copy()
    nd.maxvol_left = np.unravel_index(ind, (r1, n1), order='F')
    #The philosophical question if this index should be stored on the edge or in the node
    #The typical recomputation:
    #Take left index somewhere and update. For the first node it comes from the left edge
    #So, we can store ind_left on an edge, whereas ind_left_add in the node
    """ This is a logically separate function """
    i_left = nd.edges[0].ind_left
    #Update index
    w1 = mkron(np.ones((n1, 1), dtype=np.int32), i_left)
    w2 = mkron(reshape(np.arange(n1, dtype=np.int32),(-1, 1)), np.ones((r1, 1), dtype=np.int32))
    i_next = np.hstack((w1, w2))
    i_next = reshape(i_next, (r1 * n1, -1))
    i_next = i_next[ind, :]
    
    nd.edges[1].ind_left = i_next.copy()
    nd.edges[1].ind_left_add = i_next.copy()
    
    
def right_qr_maxvol(nd):
    cr = nd.vcore.copy()
    r1, n, r2 = cr.shape
    Rv = nd.edges[1].Rv.copy()
    cr = np.tensordot(cr, Rv, 1)
    r2 = cr.shape[2]
    cr = reshape(cr, (r1, -1))
    cr = cr.T
    q, Rv = np.linalg.qr(cr)
    ind = maxvol(q)
    Rv = np.dot(q[ind, :], Rv)
    q = np.linalg.solve(q[ind, :].T, q.T).T
    nd.edges[0].Rv = Rv.T.copy()
    q = reshape(q.T, (-1, n, r2))
    nd.vcore = q.copy()
    nd.maxvol_right = np.unravel_index(ind, (n, r2), order='F')
    """ Recomputation of right indices goes here """ 
    i_right = nd.edges[1].ind_right
    w2 = mkron(np.ones((n, 1), dtype=np.int32), i_right)
    w1 = mkron(np.ones((r2, 1), dtype=np.int32), reshape(np.arange(n, dtype=np.int32),(-1, 1)))
    i_next = np.hstack((w1, w2))
    i_next = reshape(i_next, (n * r2, -1))
    i_next = i_next[ind, :]
    nd.edges[0].ind_right = i_next.copy()
    nd.edges[0].ind_right_add = i_next.copy()
    
def apply_Ru(nd):
    cr = nd.ucore.copy()
    Ru = nd.edges[0].Ru.copy()
    cr = np.tensordot(Ru, cr, 1)
    nd.ucore = cr
    nd.edges[0].Ru = []

def compute_uadd(nd):
    cr = nd.ucore.copy()
    n = cr.shape[1]
    #Compute uadd 
    #Form full index
    i_left = nd.edges[0].ind_left
    r1 = i_left.shape[0]
    i_right_add = nd.edges[1].ind_right_add
    radd = i_right_add.shape[0]
    r2 = cr.shape[2]
    #print 'u has the size %d x %d' % (r1 * n, r2)
    #print 'uadd will have the size %d x %d' % ((r1 * n), radd)
    w1 = mkron(np.ones((radd * n, 1),dtype=np.int32), i_left)
    w2 = mkron(np.ones((r1 * n, 1), dtype=np.int32), i_right_add)
    p = np.arange(n, dtype=np.int32); p = reshape(p, (-1, 1))
    w3 = mkron(mkron(np.ones((radd, 1)), p), np.ones((r1, 1)))
    J = np.hstack((w1, w3, w2))
    #print 'J:', J
    #print 'i_right_add:', i_right_add
    #print 'i_left:', i_left
    
    uadd = c.fun(J)
    uadd = reshape(uadd, (-1, radd))
    u = reshape(cr, (-1, r2))
    ind = nd.maxvol_left
    ind = np.ravel_multi_index(ind, (r1, n), order='F')
    #Now update 
    #uadd = u * Phi
    #uadd[ind, :] = Phi
    #er = uadd - u * uadd[ind, :]
    #print 'u = ', u
    #print 'uadd = ', uadd
    comp_u = uadd - np.dot(u, uadd[ind, :])
    
    #print 'er in u:', np.linalg.norm(comp_u), 'rank=', u.shape[1]
    print 'error in u:', np.linalg.norm(comp_u)
    #print 'compu_u is', comp_u.shape
    #comp_u, tmp = np.linalg.qr(comp_u)
    ifilt = filter(lambda x: x not in ind, xrange(comp_u.shape[0]))
    c1 = comp_u[ifilt, :]
    c1, tmp = np.linalg.qr(c1)
    comp_u[ifilt, :] = c1
    #Do a slight fix
    
    ind_add = maxvol(comp_u)
    uv = u[ind_add, :]
    u2 = np.linalg.solve(comp_u[ind_add, :].T, comp_u.T).T
    u1 = u - np.dot(u2, u[ind_add, :])
    u = np.hstack((u1, u2))
    nd.ucore = reshape(u.copy(), (r1, n, -1)) #Save the current core
    Ru = np.vstack((np.eye(r2), uv)) #Correction of the product
    try:
        nd.edges[1].Ru = np.dot(Ru, nd.edges[1].Ru)
    except:
        nd.edges[1].Ru = Ru.copy()
    ind = np.hstack((ind, ind_add))
    nd.maxvol_left = np.unravel_index(ind, (r1, n), order='F')
    #And also recompute the next index
    i_left = nd.edges[0].ind_left
    #Update index full
    w1 = mkron(np.ones((n, 1), dtype=np.int32), i_left)
    w2 = mkron(reshape(np.arange(n, dtype=np.int32),(-1, 1)), np.ones((r1, 1), dtype=np.int32))
    i_next = np.hstack((w2, w1))
    i_next = reshape(i_next, (r1 * n, -1))
    #i_next = i_next[ind, :]
    
    nd.edges[1].ind_left = i_next[ind, :].copy()
    nd.edges[1].ind_left_add_new = i_next[ind_add, :].copy()
    #print 'ind_left_add_new', nd.edges[1].ind_left_add_new
    #print 'ind:', ind
    #print 'ind_add:', ind_add
    
def apply_Rv(nd):
    cr = nd.vcore.copy()
    Rv = nd.edges[1].Rv.copy()
    cr = np.tensordot(cr, Rv, 1)
    nd.vcore = cr
    nd.edges[1].Rv = []
    
    
def compute_vadd(nd):
    cr = nd.vcore.copy()
    n = cr.shape[1]
    i_right = nd.edges[1].ind_right
    r2 = i_right.shape[0]
    i_left_add = nd.edges[0].ind_left_add
    radd = i_left_add.shape[0]
    r1 = cr.shape[0]
    #print 'vadd will have shape %d x %d' % (n * r2, radd)
    #print 'v will have have shape %d x %d' % (n * r2, r1)
    w1 = mkron(np.ones((r2 * n, 1),dtype=np.int32), i_left_add)
    #w2 = mkron(np.ones((radd * n, 1), dtype=np.int32), i_right)
    try: 
        w2 = mkron(i_right, np.ones((radd * n, 1), dtype=np.int32))
    except:
        w2 = np.ones((radd * n, 1), dtype=np.int32)
    p = np.arange(n, dtype=np.int32); p = reshape(p, (-1, 1))
    w3 = mkron(mkron(np.ones((r2, 1)), p), np.ones((radd, 1)))
    J = np.hstack((w1, w3, w2))
    #print 'J:', J
    #print 'i_left_add:', i_left_add
    #print 'i_right:', i_right
    vadd = c.fun(J)
    vadd = reshape(vadd, (radd, -1))
    v = reshape(cr, (r1, -1))
    v = v.T
    vold = v.copy()

    vadd = vadd.T
    ind = nd.maxvol_right
    ind = np.ravel_multi_index(ind, (n, r2), order='F')
    #Now update 
    comp_v = vadd - np.dot(v, vadd[ind, :])
    #print 'vadd:', vadd, 'comp_v:', comp_v, 'v', v
    #raw_input()
    print 'error in v:', np.linalg.norm(comp_v)
    #raw_input()
    #print v[ind, :]
    #raw_input()
    #print np.linalg.norm(comp_v)
    comp_v, tmp = np.linalg.qr(comp_v)
    ind_add = maxvol(comp_v)
    uv = v[ind_add, :]
    v2 = np.linalg.solve(comp_v[ind_add, :].T, comp_v.T).T
    v1 = v - np.dot(v2, v[ind_add, :])
    v = np.hstack((v1, v2))
    nd.vcore = reshape(v.copy().T, (-1, n, r2)) #Save the current core
    Rv = np.vstack((np.eye(r1), uv)) #Correction of the product
    #print 'v:', v
    #print 'er:',  vold - np.dot(v, Rv)
    #print 'old Rv', nd.edges[0].Rv
    #raw_input()

    try:
        nd.edges[0].Rv = np.dot(nd.edges[0].Rv, Rv.T)
    except:
        nd.edges[0].Rv = Rv.T.copy()

    ind = np.hstack((ind, ind_add))
    nd.maxvol_right = np.unravel_index(ind, (n, r2), order='F')
    
    """ Finally, update indices """
    i_right = nd.edges[1].ind_right
    w2 = mkron(np.ones((n, 1), dtype=np.int32), i_right)
    w1 = mkron(np.ones((r2, 1), dtype=np.int32), reshape(np.arange(n, dtype=np.int32),(-1, 1)))
    i_next = np.hstack((w2, w1))
    i_next = reshape(i_next, (n * r2, -1))

    nd.edges[0].ind_right = i_next[ind, :].copy()
    nd.edges[0].ind_right_add_new = i_next[ind_add, :].copy()

def setup_indices(c):
    d = c.d
    #Setup left indices
    for i in xrange(d-1):
        nd = c.nodes[i]
        left_qr_maxvol(nd)  
    
    for i in xrange(d-1, 0, -1):
        nd = c.nodes[i]
        #compute_add(nd)
        right_qr_maxvol(nd)

def iterate(c):
    for i in xrange(d):
        c.nodes[i].edges[0].Rv = np.ones((1, 1))
        c.nodes[i].edges[1].Rv = np.ones((1, 1))
        c.nodes[i].edges[0].Ru = np.ones((1, 1))
        c.nodes[i].edges[1].Ru = np.ones((1, 1))

    #Update u
    #print reshape(np.tensordot(c.nodes[0].ucore, c.nodes[1].ucore, 1), (4, -1))
    for i in xrange(d-1):
        apply_Ru(c.nodes[i])
        #w2 = reshape(np.tensordot(c.nodes[1].vcore, c.nodes[2].vcore, 1), (-1, 16))
        #w2 = w2.T
        #Modifying one link
        for j in xrange(3): #Size of local enrichment
            try:
                c.nodes[i+1].edges[0].ind_right_add = c.nodes[i+1].edges[0].ind_right_add_new.copy()
            except:
                pass
            compute_uadd(c.nodes[i])
            try:
                c.nodes[i].edges[1].ind_left_add = c.nodes[i].edges[1].ind_left_add_new.copy()
            except:
                pass
            #print 'i = ', i, c.nodes[i].edges[1].ind_left_add
            #First we look at the node[1]
            compute_vadd(c.nodes[i+1])
            #w2 = reshape(np.tensordot(c.nodes[1].vcore, c.nodes[2].vcore, 1), (-1, 16))
            #print 'w2:', w2.T
            #w3 = c.nodes[1].vcore
            #r1 = w3.shape[0]
            #w3 = reshape(w3, (r1, -1))
            #w3 = w3.T
            #print 'w3:', w3
            #raw_input()
            #print 'Shapes:', c.nodes[1].vcore.shape, c.nodes[2].vcore.shape
        apply_Rv(c.nodes[i])

        #w1 = reshape(np.tensordot(c.nodes[1].vcore, c.nodes[2].vcore, 1), (-1, 16))
        #w1 = w1.T
        
        #print w1.shape
        #if i == 1:
        #    print 'diff', np.linalg.norm(w1 - w2)
        #    raw_input()


            #print c.nodes[0].vcore.shape, c.nodes[1].vcore.shape, c.nodes[2].vcore.shape

            #apply_Rv(c.nodes[i+1]) 

    
    
    """
    for i in xrange(d-1):
        compute_uadd(c.nodes[i])
        #if i == 0:
        #    w = c.nodes[1].ucore.copy()
        #    w = np.tensordot(c.nodes[1].edges[0].Ru, w, 1)
        #    print reshape(np.tensordot(c.nodes[0].ucore, w, 1), (9, -1))
    
    for i in xrange(d-1, 0, -1):
        nd = c.nodes[i]
        compute_vadd(nd)
    
    #Now copy add_new -> add
    for i in xrange(d-1):
        c.nodes[i].edges[1].ind_left_add = c.nodes[i].edges[1].ind_left_add_new.copy()
    
    for i in xrange(d-1, 0, -1):
        c.nodes[i].edges[0].ind_right_add = c.nodes[i].edges[0].ind_right_add_new.copy()
    #Update v
       """

# %%
def myfun(x):
    return (x.sum(axis=1))
    #return (x + 1).prod(axis=1)

d = 3
n = 40
r = 1

sz = [n] * d
ind_all = np.unravel_index(np.arange(n ** d), sz)
ind_all = np.array(ind_all).T
ft = reshape(myfun(ind_all), sz)
#x0 = tt.tensor(ft, 1e-8)

x0 = tt.rand(n, d, r)

# %%
#return np.ones(x.shape[0])
niters = 4 #Total number of iterations
c = init_alg(myfun, x0)
setup_indices(c)

for i in xrange(niters):
    print 'swp:', i
    iterate(c)
    Y = get_uY(c)
# Out:
# swp: 0
# error in u: 556.190802046
# error in v: 692.43681624
# error in u: 9.169375601
# error in v: 26.4541761642
# error in u: 2.21069018183e-13
# error in v: 3.48093428611e-14
# error in u: 983.381091012
# error in v: 700.648942243
# error in u: 12.9619252543
# error in v: 72.0393037428
# error in u: 1.3788912041e-12
# error in v: 4.08175725862e-14
# swp: 1
# error in u: 3.62307127488e-14
# error in v: 802.430600601
# error in u: 6.70324676268e-14
# error in v: 248.631771174
# error in u: 5.50384036474e-14
# error in v: 1.4836567898e-13
# error in u: 1.32692785804e-13
# error in v: 3.25611587112e-14
# error in u: 1.36120406045e-13
# error in v: 2.84217094304e-14
# error in u: 1.63733469404e-13
# error in v: 3.01457752067e-14
# swp: 2
# error in u: 7.51967749882e-14
# error in v: 1.56793052302e-13
# error in u: 5.94482704155e-14
# error in v:
#  9.54781473466e-14
# error in u: 4.49386683978e-14
# error in v: 2.56583662196e-13
# error in u: 2.80866677486e-13
# error in v: 4.76646557423e-14
# error in u: 3.6094591869e-13
# error in v: 3.17764371616e-14
# error in u: 2.93308736453e-13
# error in v: 0.0
# swp: 3
# error in u: 7.65277946916e-14
# error in v: 2.49298250208e-13
# error in u: 2.92964275105e-14
# error in v: 1.67166410222e-13
# error in u: 3.09718398025e-14
# error in v: 1.68520006492e-13
# error in u: 3.76227178638e-13
# error in v: 7.1054273576e-15
# error in u: 3.71632361135e-13
# error in v: 2.00971834712e-14
# error in u:
#  6.65154915017e-13
# error in v: 0.0

# %%
from copy import deepcopy
c0 = deepcopy(c)

# %%
c = deepcopy(c0)
iterate(c)
# Out:
# error in u: 0.0
# i =  0 [[1]]
# J: [[ 1.  0.  3.]
#  [ 1.  1.  0.]
#  [ 1.  2.  3.]
#  [ 1.  3.  0.]
#  [ 1.  0.  3.]
#  [ 1.  1.  0.]
#  [ 1.  2.  3.]
#  [ 1.  3.  0.]]
# i_left_add: [[1]]
# i_right: [[3]
#  [0]]
# vadd: [[  8.]
#  [  4.]
#  [ 24.]
#  [  8.]
#  [  8.]
#  [  4.]
#  [ 24.]
#  [  8.]] comp_v: [[  0. ]
#  [  0. ]
#  [ 20.4]
#  [  0. ]
#  [  6. ]
#  [  3. ]
#  [ 23.1]
#  [  6. ]] v [[ 0.      1.    ]
#  [ 0.5     0.    ]
#  [ 0.85   -0.4   ]
#  [ 1.      0.    ]
#  [ 0.      0.25  ]
#  [ 0.125   0.    ]
#  [ 0.2125 -0.1   ]
#  [ 0.25    0.    ]]
# error in v: 32.1056069869
# error in u: 0.0
# i =  1 [[0 3]]
# J: [[ 0.  3.  0.]
#  [ 0.  3.  1.]
#  [ 0.  3.  2.]
#  [ 0.  3.  3.]]
# i_left_add: [[0 3]]
# i_right: []
# vadd: [[  4.]
#  [  8.]
#  [ 12.]
#  [ 16.]] comp_v: [[ 0.]
#  [ 0.]
#  [ 0.]
#  [ 0.]] v [[ 0.    1.  ]
#  [ 0.5  -0.  ]
#  [ 0.75 -0.  ]
#  [ 1.   -0.  ]]
# error in v: 0.0

# %%
w1 = reshape(np.tensordot(c.nodes[1].vcore, c.nodes[2].vcore, 1), (-1, 16)).T
w2 = reshape(c.nodes[2].vcore, (-1, 4)).T
#print w1
ii = [15, 12]
ft1 = reshape(ft, (4, -1))
ft1 = ft1[c.nodes[0].maxvol_left[1], :]
#vadd
#ft2 = reshape(ft, (16, -1))
#print np.dot(w1, ft1[:, ii].T) - ft1.T
J = [[ 1.,  0.,  3.],
 [ 1.,  1.,  0.],
 [ 1.,  2.,  3.],
 [ 1.,  3.,  0.],
 [ 1.,  0.,  3.],
 [ 1.,  1.,  0.],
 [ 1.,  2.,  3.],
 [ 1.,  3.,  0.]]
for k in J:
    print ft[tuple(k)]
print vadd
# Out:
# 8
# 4
# 24
# 8
# 8
# 4
# 24
# 8
# [[  8.]
#  [  4.]
#  [ 24.]
#  [  8.]
#  [  8.]
#  [  4.]
#  [ 24.]
#  [  8.]]

# %%
print reshape(ft1, (-1, 4))[:, c.nodes[2].maxvol_right[0]].shape
print vadd.shape
# Out:
# (8, 2)
# (8, 1)

# %%
reshape(c.nodes[2].vcore, (2, -1)).T[c.nodes[2].maxvol_right[0], :]
w0 = reshape(c.nodes[1].vcore, (2, -1)).T
ft1 = ft[:, :, :][:, :, c.nodes[2].maxvol_right[0]]
ft1.shape
ft1[1, :, :]
#ft1 = reshape(ft1, (4, 8))
#ft1 = ft1.T
#np.dot(w0, ft1[jj, :]) - ft1
# Out:
# array([[ 8,  2],
#        [16,  4],
#        [24,  6],
#        [32,  8]])

# %%
ii = [15, 12]
jj = [3, 0]
print np.dot(w1, ft1[:, ii].T) - ft1.T
#print np.dot(w2, ft2[:, jj].T) - ft2.T
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-560-f17378b2e393> in <module>()
#       1 ii = [15, 12, 2]
#       2 jj = [3, 0]
# ----> 3 print np.dot(w1, ft1[:, ii].T) - ft1.T
#       4 #print np.dot(w2, ft2[:, jj].T) - ft2.T
#
# ValueError: matrices are not aligned

# %%
# %debug
# Out:
# > /Users/ivan/anaconda/lib/python2.7/site-packages/numpy/lib/shape_base.py(751)kron()
#     750     for _ in range(nd):
# --> 751         result = concatenate(result, axis=axis)
#     752     wrapper = get_array_prepare(a, b)
# ipdb> up
# > <ipython-input-507-8bcc8cf8f16e>(14)mkron()
#      13 def mkron(a, b):
# ---> 14     return np.kron(a, b)
#      15
# ipdb> up
# > <ipython-input-683-656c5c973553>(158)compute_vadd()
#     157     #w2 = mkron(np.ones((radd * n, 1), dtype=np.int32), i_right)
# --> 158     w2 = mkron(i_right, np.ones((radd * n, 1), dtype=np.int32))
#     159     p = np.arange(n, dtype=np.int32); p = reshape(p, (-1, 1))
# ipdb> p w2.shape
# (4, 3)
# ipdb> p i_right.shape
# (1, 0)
# ipdb> q

# %%
q = c.nodes[0]
print q.maxvol_left

vadd = [[  8.],
 [  4.],
 [ 24.],
 [  8.],
 [  8.],
 [  4.],
 [ 24.],
 [  8.]]
vadd = np.array(vadd)
print vadd.shape
#print np.dot(w1, ft1[:, ii].T) - ft1.T
# Out:
# (array([0, 0]), array([3, 0]))
# (8, 1)

# %%
# %debug
# Out:
# > /Users/ivan/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.py(222)_assertNoEmpty2d()
#     221         if a.size == 0 and product(a.shape[-2:]) == 0:
# --> 222             raise LinAlgError("Arrays cannot be empty")
#     223
# ipdb> up
# > /Users/ivan/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.py(740)qr()
#     739     _assertRank2(a)
# --> 740     _assertNoEmpty2d(a)
#     741     m, n = a.shape
# ipdb> up
# > <ipython-input-703-0cf2fdacedf0>(106)compute_uadd()
#     105     c1 = comp_u[ifilt, :]
# --> 106     c1, tmp = np.linalg.qr(c1)
#     107     comp_u[ifilt, :] = c1
# ipdb> p c1
# array([], shape=(0, 1), dtype=float64)
# ipdb> up
# > <ipython-input-703-0cf2fdacedf0>(248)iterate()
#     247                 pass
# --> 248             compute_uadd(c.nodes[i])
#     249             try:
# ipdb> q
